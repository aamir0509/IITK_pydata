# %%
import pandas as pd
obj3=pd.Series(['Blue','purple','Yellow'],index=[0,2,4])
obj3
# Out:
# 0      Blue
# 2    purple
# 4    Yellow
# dtype: object

# %%
import numpy as np
obj3.reindex(np.arange(6))
z=obj3.reindex(np.arange(6))
z.isnull()

z[z.isnull()]
z[z.isnull()].index
z[z.isnull()].keys()
# Out:
# Int64Index([1, 3, 5], dtype='int64')

# %%
obj3=pd.Series(['Blue','purple','Yellow'],index=[0,2,4])
a=obj3.reindex(np.arange(6), method='ffill')

a
# Out:
# 0      Blue
# 1      Blue
# 2    purple
# 3    purple
# 4    Yellow
# 5    Yellow
# dtype: object

# %%
data=pd.DataFrame(np.arange(16).reshape(([4,4])),
                  index=['ohio','colorado','utah','New York'],
                  columns=['one','two','th','four'])

data.loc['utah']
data.loc['utah':'dsfsdf']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8277c0bdb2f3> in <module>()
# ----> 1 data=pd.DataFrame(np.arange(16).reshape(([4,4])),
#       2                   index=['ohio','colorado','utah','New York'],
#       3                   columns=['one','two','th','four'])
#       4
#       5 data.loc['utah']
#
# NameError: name 'pd' is not defined

# %%
data.iloc[0:2,0:2]
# Out:
#           one  two
# ohio        0    1
# colorado    4    5

# %%
data.iloc[0:2,:]
# Out:
#           one  two  th  four
# ohio        0    1   2     3
# colorado    4    5   6     7

# %%
resto=pd.DataFrame(pd.read_csv('https://bit.ly/2UUomN0',sep='\t'))
New_Data=resto[['item_name','item_price']]

New_Data.drop_duplicates(subset ="item_name")

New_Data
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# 5                              Chicken Bowl    $10.98
# 6                             Side of Chips     $1.69
# 7                             Steak Burrito    $11.75
# 8                          Steak Soft Tacos     $9.25
# 9                             Steak Burrito     $9.25
# 10                      Chips and Guacamole     $4.45
# 11                     Chicken Crispy Tacos     $8.75
# 12                       Chicken Soft Tacos     $8.75
# 13                             Chicken Bowl    $11.25
# 14                      Chips and Guacamole     $4.45
# 15    Chips and Tomatillo-Green Chili Salsa     $2.39
# ...

# %%
oc=resto[['item_price','item_name','quantity']]
oc['item_price'] = oc['item_price'].str.replace('$', '')
oc['item_price'] = oc['item_price'].str.replace(' ', '')
#oc['item_price'] = oc['item_price'].astype(float)




oc['item_price']=pd.to_numeric(oc['item_price'])

oc.item_price.argmax()

resto.iloc[oc.item_price.argmax()]
#oc.dtypes

#resto.groupby('item_price').size()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
temp=resto[resto['item_name'] =='Veggie Salad Bowl']
temp["quantity"].sum()
#count = resto["item_name"].str.count("Veggie Salad Bowl") 
#count.max()
# Out:
# 18

# %%
temp=resto[(resto['quantity']>1) & (resto['item_name'] =='Chicken Bowl')].count()
temp
# Out:
# order_id              33
# quantity              33
# item_name             33
# choice_description    33
# item_price            33
# dtype: int64

# %%
z=pd.DataFrame(np.random.randint(0,9,(3,3)))

z.replace(1,2)
z.replace({3:4,4:11})
# Out:
#     0  1  2
# 0  11  2  4
# 1  11  0  0
# 2   5  2  4

# %%
media=pd.read_csv('https://bit.ly/1N5br3h',sep=',', names=["S-L", "S-W", "P-L", "P-W","Class"])

media.isnull()
# Out:
#        S-L    S-W    P-L    P-W  Class
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False  False  False  False  False
# 5    False  False  False  False  False
# 6    False  False  False  False  False
# 7    False  False  False  False  False
# 8    False  False  False  False  False
# 9    False  False  False  False  False
# 10   False  False  False  False  False
# 11   False  False  False  False  False
# 12   False  False  False  False  False
# 13   False  False  False  False  False
# 14   False  False  False  False  False
# 15   False  False  False  False  False
# 16   False  False  False  False  False
# 17   False  False  False  False  False
# 18   False  False  False  False  False
# 19   False  False  False  False  False
# 20   False  False  False  False  False
# 21   False  False  False  False  False
# 22   False  False  False  False  False
# ...

# %%
df = media.drop('Class', 1)
df
# Out:
#      S-L  S-W  P-L  P-W
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1
# 13   4.3  3.0  1.1  0.1
# 14   5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# 27   5.2  3.5  1.5  0.2
# 28   5.2  3.4  1.4  0.2
# 29   4.7  3.2  1.6  0.2
# ..   ...  ...  ...  ...
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# ...

# %%
df = media
df["P-L"].iloc[9:29] = np.nan
df
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#      S-L  S-W  P-L  P-W           Class
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  NaN  0.1     Iris-setosa
# 10   5.4  3.7  NaN  0.2     Iris-setosa
# 11   4.8  3.4  NaN  0.2     Iris-setosa
# 12   4.8  3.0  NaN  0.1     Iris-setosa
# 13   4.3  3.0  NaN  0.1     Iris-setosa
# ...

# %%
Df2=df.dropna(axis=0) #delete coloumn row having nan

# %%
Df2.reset_index()
# Out:
#      index  S-L  S-W  P-L  P-W           Class
# 0        0  5.1  3.5  1.4  0.2     Iris-setosa
# 1        1  4.9  3.0  1.4  0.2     Iris-setosa
# 2        2  4.7  3.2  1.3  0.2     Iris-setosa
# 3        3  4.6  3.1  1.5  0.2     Iris-setosa
# 4        4  5.0  3.6  1.4  0.2     Iris-setosa
# 5        5  5.4  3.9  1.7  0.4     Iris-setosa
# 6        6  4.6  3.4  1.4  0.3     Iris-setosa
# 7        7  5.0  3.4  1.5  0.2     Iris-setosa
# 8        8  4.4  2.9  1.4  0.2     Iris-setosa
# 9       29  4.7  3.2  1.6  0.2     Iris-setosa
# 10      30  4.8  3.1  1.6  0.2     Iris-setosa
# 11      31  5.4  3.4  1.5  0.4     Iris-setosa
# 12      32  5.2  4.1  1.5  0.1     Iris-setosa
# 13      33  5.5  4.2  1.4  0.2     Iris-setosa
# 14      34  4.9  3.1  1.5  0.1     Iris-setosa
# 15      35  5.0  3.2  1.2  0.2     Iris-setosa
# 16      36  5.5  3.5  1.3  0.2     Iris-setosa
# 17      37  4.9  3.1  1.5  0.1     Iris-setosa
# 18      38  4.4  3.0  1.3  0.2     Iris-setosa
# ...

# %%
print(df['P-L'].max())
print(df['P-W'].max())
print(df['S-L'].max())
print(df['S-W'].max())
# Out:
# 6.9
# 2.5
# 7.9
# 4.4

# %%
df.describe()
# Out:
#               S-L         S-W         P-L         P-W
# count  150.000000  150.000000  130.000000  150.000000
# mean     5.843333    3.054000    4.109231    1.198667
# std      0.828066    0.433594    1.631019    0.763161
# min      4.300000    2.000000    1.200000    0.100000
# 25%      5.100000    2.800000    3.350000    0.300000
# 50%      5.800000    3.000000    4.500000    1.300000
# 75%      6.400000    3.300000    5.200000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
Groupediris=media.groupby('Class')
Groupediris.first()
# Out:
#                  S-L  S-W  P-L  P-W
# Class
# Iris-setosa      5.1  3.5  1.4  0.2
# Iris-versicolor  7.0  3.2  4.7  1.4
# Iris-virginica   6.3  3.3  6.0  2.5

# %%
Groupediris.describe()
# Out:
#                   S-L                               ...  P-W
#                 count   mean       std  min    25%  ...  min  25%  50%  75%  max
# Class                                               ...
# Iris-setosa      50.0  5.006  0.352490  4.3  4.800  ...  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor  50.0  5.936  0.516171  4.9  5.600  ...  1.0  1.2  1.3  1.5  1.8
# Iris-virginica   50.0  6.588  0.635880  4.9  6.225  ...  1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %%
incomes=pd.Series(np.random.randint(100000,1000000,(10000,)))

bins=[100000,300000,700000,1000000]

curr_arr=pd.cut(incomes,bins,labels=['low','medium','high'])
# Out:
# medium    4404
# high      3368
# low       2228
# dtype: int64

# %%
curr_arr.head()
# Out:
# 0       low
# 1      high
# 2      high
# 3      high
# 4    medium
# dtype: category
# Categories (3, object): [low < medium < high]

# %%
incomes.head()
# Out:
# 0    269546
# 1    827794
# 2    972205
# 3    755386
# 4    441041
# dtype: int64

# %%
curr_arr.value_counts()
# Out:
# medium    4404
# high      3368
# low       2228
# dtype: int64

# %%
pd.cut(incomes,4).value_counts()
# Out:
# (550057.0, 774998.0]     2534
# (774998.0, 999939.0]     2506
# (325116.0, 550057.0]     2481
# (99275.236, 325116.0]    2479
# dtype: int64
